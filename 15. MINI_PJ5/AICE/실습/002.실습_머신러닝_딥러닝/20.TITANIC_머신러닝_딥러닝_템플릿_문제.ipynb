# %% [markdown]
# # 머신러닝, 딥러닝 TITANIC템플릿(HARD)

# %% [markdown]
# ## > 머신러닝, 딥러닝 TITANIC템플릿 목적
# - 간단하게 쉽게 머신러닝, 딥러닝 모델링 만들기
# - 잘 몰라도 아래 순서에 맞게 , 이런식으로 실행하면 되겠구나 느끼기
# - 여러분이 처음 한다고 생각하고 템플릿 작성함

# %% [markdown]
# ## > 모델링 프로세스
# 1. 데이터 가져오기
# 2. 데이터 분석
# 3. 전처리
# 4. X, y 나누기
# 5. Train , Test 데이터셋 나누기
# 6. 머신러닝 모델링
# 7. 딥러닝 모델링
# 8. 딥러닝 성능 평가

# %% [markdown]
# ---

# %% [markdown]
# # 1. 데이터 가져오기
# - 먼저, 데이터가 있어야 모델링을 만들수 있다.
# - 데이터 가져오는 방법에는 여러가지 있다.
#  - 본인 데이터를 직접 올리는 방법
#  - 기존에 제공하는 데이터 가져다 쓰는 방법

# %%
# 필요한 라이브러리 가져오기
# 그냥 무조건 가져온다고 생각하자 : pandas, numpy, seaborn, matplotlib.pyplot
# seaborn 설치가 되어 있지 않으면 라이브러리는 설치 필요 : !pip install seaborn

# %%
# Seaborn에서 제공하는 데이터셋 확인하기
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# #### 타이타닉 데이터셋 가져오기

# %% [markdown]
# ![타이타닉](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQav_aQ5prV7GD__U3dvOt8mkxzA6LAGd8Gfg&usqp=CAU)

# %%
# 많이 사용하는 데이터는 'iris' , 'tips' , 'titanic'
# 이번에 titanic 데이터셋 가져오기 
# seaborn load_dataset('titanic') 함수 활용 : 결과 titanic 저장

# %%
# 가져온 titanic 데이터 확인 하기
# 자동으로 판다스 데이터프레임 형식으로 읽어짐
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# 타이타닉 데이터에 대한 전체적인 정보 보기 : info 함수
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# #### 타이타닉 Data Dictionary
# - survived : 생존=1, 죽음=0
# - pclass : 승객 등급. 1등급=1, 2등급=2, 3등급=3
# - sibsp : 함께 탑승한 형제 또는 배우자 수
# - parch : 함께 탑승한 부모 또는 자녀 수
# - ticket : 티켓 번호
# - cabin : 선실 번호
# - embarked : 탑승장소 S=Southhampton, C=Cherbourg, Q=Queenstown

# %% [markdown]
# # 2. 데이터 분석
# - 눈으로 데이터 수치를 보고 어떤 흐름인지 파악할수 있지만,
# - 시각화를 통한다면 쉽게 흐름을 파악할수 있으니, 할수 있으면 사용해라.
# - 여러분에게는 어려울수 있으니, 아, 이렇게 데이터를 가지고 시각화를 할수 있구나 느낀면 된다.

# %%
# 간단하게 시각화해 보기
# 여러분은 잘 모르지만, 나중에 이렇게 시각화를 할수 있구나 알기

# 판다스 value_counts 함수 이용해서 survived 컬럼 값 분포 확인
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
# survived 컬럼 값 분포 확인에 대한 바차트 그리기

# %%
# 판다스 value_counts 함수 이용해서 pclass 값 분포 확인
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
# 판다스 value_counts 함수 이용해서 pclass 값 분포에 대한 바차트

# %%
# 판다스 value_counts 함수 이용해서 sex 값 분포에 대한 바차트

# %%
# age 컬럼에 대한 box 차트
# 나이 분포를 볼때 중간값이 26 정도 되며, 전체적으로 나이가 많은쪽으로 넓게 있다.

# %%
# seaborn boxplot 이용하여 pclass별로 age 분포 확인.(data=titanic, x='pclass', y='age')
# 1등급에 나이 있는 분들이 더 많고 등급이 낮아질수록 나이가 어리다.

# %%
# boxplot 이용하여 pclass별로 age 분포 확인. 또한 survived 키로 분류해 보자.(hue='survived')
# 1등급에 있는 분들이 다른 등급에 있는 분들보다 더 많이 살아남았음 알수 있따.

# %%
# pclass별로 어느정도 살아 남았는지 확인 : pclass에 대해 groupby 하고 survived 컬럼에 대한 평균값 구하기
# groupby 한 결과를 pclass_grp 변수에 저장하고 출력하기
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
# pclass_grp 데이터프레임에서 x='pclass', y='survived' 해서 bar 차트 그리기

# %% [markdown]
# ---

# %% [markdown]
# # 3. 전처리
# - 전처리를 왜 해야 할까요?
# - 불필요한 컬럼을 삭제하거나, 빈공간을 채우기등
# - 모든 데이터가 컴퓨터가 이해할수 있는 숫자로 되어야 한다.
# - 결국, 깔끔하고 깨끗한 숫자형 데이터로 만들어야 한다.

# %%
# 타이타닉 정보 보기 : info 함수
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# 중복 컬럼 삭제 : class, alive 
# 판다스 drop 함수 활용 : ['class', 'alive'], axis=1, inplace=True

# %%
# 내용을 간단하기 위해서 편의대로 컬럼을 drop함수 활용하여 삭제 : 'embarked', 'who', 'adult_male', 'deck', 'embark_town', 'alone'
# 옵션 : axis=1, inplace=True

# %%
# 타이타닉 내용 앞 5개 보기 : head 함수
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
# sex 컬럼에 대해 male : 0 , female : 1로 변환 
# 판다스 replace 함수 활용 : ['male', 'female'], [0, 1], inplace=True

# %%
# 타이타닉 내용 뒤 5개 보기 : tail 함수
# Out:
#      survived  pclass  sex   age  sibsp  parch   fare
# 886         0       2    0  27.0      0      0  13.00
# 887         1       1    1  19.0      0      0  30.00
# 888         0       3    1   NaN      1      2  23.45
# 889         1       1    0  26.0      0      0  30.00
# 890         0       3    0  32.0      0      0   7.75

# %%
# null 여부 확인
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# dtype: int64

# %%
# 1. age컬럼에 대한 평균값 구하고 age_mean 변수에 저장
# 2. 판다스 fillna로 age 중간값으로 채우자. (inplace=True)

# %%
# null 여부 다시 확인
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# dtype: int64

# %% [markdown]
# # 4. X, y 나누기
# - 지도학습 경우 데이터와 정답이 있어야 합니다.
# - 데이터에 해당하는 X와 정답에 해당하는 y가 있어야 합니다.
# - 아래와 같이 판다스를 이용하면 X, y를 쉽게 나눌수 있어요

# %%
# 다시 한번 타이타닉 데이터셋 보기
# 타이타닉 데이터 앞 5개 보기 : head 함수
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare
# 0         0       3    0  22.0      1      0   7.2500
# 1         1       1    1  38.0      1      0  71.2833
# 2         1       3    1  26.0      0      0   7.9250
# 3         1       1    1  35.0      1      0  53.1000
# 4         0       3    0  35.0      0      0   8.0500

# %%
# X 분리 
# 판다스 drop 함수 활용하여 'survived' 컬럼 삭제하고 나머지를 X에 저장

# %%
# 분리된 X 데이터 앞 5개 보기 : head 함수
# Out:
#    pclass  sex   age  sibsp  parch     fare
# 0       3    0  22.0      1      0   7.2500
# 1       1    1  38.0      1      0  71.2833
# 2       3    1  26.0      0      0   7.9250
# 3       1    1  35.0      1      0  53.1000
# 4       3    0  35.0      0      0   8.0500

# %%
# y 분리 
# survived 컬럼값을 y에 저장한다.

# %%
# 분리된 y 확인
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
# Series, DataFrame 형태를 numpy array 변경하기 
# 뒤쪽에서 타입이 맞지 않아서 에러 날수 있기 때문에
# X.values , y.values --> X , y 입력

# %%
print(X[:2])
print(y[:2])
# Out:
# [[ 3.      0.     22.      1.      0.      7.25  ]
#  [ 1.      1.     38.      1.      0.     71.2833]]
# [0 1]

# %% [markdown]
# ---

# %% [markdown]
# # 5. Train , Test 데이터셋 나누기
# - 데이터를 가지고 모델을 학습 시키고 나서 모델 평가를 해야 하는데
# - 모델이 학습한 데이터를 가지고 평가를 하지 않고
# - 모델이 모르는 데이터로 평가를 해야 공정하고 평가 결과가 잘 나온다면 배포(일반화) 가능하다.

# %%
# Train / Test 데이터셋 나누어주는 함수 : train_test_split

from sklearn.model_selection import train_test_split

# %%
# train_test_split 함수 활용
# 입력 : X, y 
# Train : Test => 8 : 2  비율로 나누기 : test_size=0.2
# 매번 같은 결과 나오도록 값 고정 : random_state=42
# 결과 저장 : X_train, X_test, y_train, y_test

# %%
# Train 과 Test 데이터셋 사이즈 확인
# X_train.shape, X_test.shape, y_train.shape, y_test.shape 확인
# Out:
# ((712, 6), (179, 6), (712,), (179,))

# %% [markdown]
# ---

# %% [markdown]
# # 6. 머신러닝 모델링
# - DecisionTree 결정트리
# - RandomForest 앙상블

# %% [markdown]
# #### DecisionTree

# %% [markdown]
# ![결정트리](http://gavinln.github.io/blog-site/img/decision_trees/tree-depth-2.png)

# %%
# DecisionTree 머신러닝 모델링
from sklearn.tree import DecisionTreeClassifier

# %%
# 1. DecisionTreeClassifier 모델 정의 -> dt 저장
# 2. dt 모델 학습(fit) : X_train, y_train
# 3. dt 모델 성능확인(score) : X_test, y_test
# Out:
# 0.7541899441340782

# %% [markdown]
# #### RandomForest

# %% [markdown]
# ![RandomForest](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FdDE2Rk%2FbtqvUzlulvU%2F6UbCGO8rHAhDJDCE3dyRr0%2Fimg.png)

# %%
# RandomForest 머신러닝 모델링
from sklearn.ensemble import RandomForestClassifier

# %%
# 1. RandomForestClassifier 모델 정의 -> rf 저장
# 2. rf 모델 학습(fit) : X_train, y_train
# 3. rf 모델 성능확인(score) : X_test, y_test
# Out:
# 0.8156424581005587

# %%
# X_test 첫번째 데이터 보기
# Out:
# array([ 3.        ,  0.        , 29.69911765,  1.        ,  1.        ,
#        15.2458    ])

# %%
# 예측해 보기
# rf 모델 predict 함수 활용 
# 입력 : 첫번재 데이터 --> [X_test[0]]
# 예측 결과를 rf_pred 저장 및 출력
# Out:
# array([0])

# %% [markdown]
# ---

# %% [markdown]
# # 7. 딥러닝 모델링

# %%
# 딥러닝 필요한 라이브러리 가져오기

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ![DNN](https://www.kdnuggets.com/wp-content/uploads/neural-network-input-hidden-output.jpg)

# %%
# Sequential 모델 만들기 --> model 변수 저장
# input layer : (6, )
# hidden layer : 10 unit , activation='relu'
# output layer : 2 unit , activation='softmax'

# %%
# 모델 컴파일 : compile
# loss='sparse_categorical_crossentropy'
# optimizer='adam'
# metrics=['accuracy']

# %%
# 모델 학습 : fit
# X_train, y_train, epochs=10, batch_size=8
# 학습결과 저장 : history
# Out:
# Epoch 1/10
# 89/89 [==============================] - 1s 3ms/step - loss: 1.5970 - accuracy: 0.5885
# Epoch 2/10
# 89/89 [==============================] - 0s 2ms/step - loss: 0.8267 - accuracy: 0.6966
# Epoch 3/10
# 89/89 [==============================] - 0s 4ms/step - loss: 0.6664 - accuracy: 0.7107
# Epoch 4/10
# 89/89 [==============================] - 0s 2ms/step - loss: 0.6149 - accuracy: 0.7402
# Epoch 5/10
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5886 - accuracy: 0.7079
# Epoch 6/10
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5709 - accuracy: 0.7360
# Epoch 7/10
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5357 - accuracy: 0.7374
# Epoch 8/10
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.7444
# Epoch 9/10
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5350 - accuracy: 0.7570
# Epoch 10/10
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5050 - accuracy: 0.7626

# %% [markdown]
# ## epochs 늘려 좀더 공부시키자.
# - 아무리 공부해도 성능이 더 이상 오르지 않는구나

# %%
# epochs 횟수 증가하여 모델 학습 : fit
# X_train, y_train, epochs=30, batch_size=8 --> epochs 30으로 변경
# 학습결과 저장 : history
# Out:
# Epoch 1/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.4970 - accuracy: 0.7669
# Epoch 2/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5240 - accuracy: 0.7683
# Epoch 3/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.4865 - accuracy: 0.7697
# Epoch 4/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4941 - accuracy: 0.7753
# Epoch 5/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4869 - accuracy: 0.7725
# Epoch 6/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4751 - accuracy: 0.7781
# Epoch 7/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.4764 - accuracy: 0.7753
# Epoch 8/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.4693 - accuracy: 0.7963
# Epoch 9/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.4722 - accuracy: 0.7865
# Epoch 10/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.4618 - accuracy: 0.7935
# Epoch 11/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.4622 - accuracy: 0.7851
# Epoch 12/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.4630 - accuracy: 0.7865
# Epoch 13/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4746 - accuracy: 0.7893
# Epoch 14/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.4647 - accuracy: 0.7907
# Epoch 15/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4912 - accuracy: 0.7893
# Epoch 16/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4624 - accuracy: 0.7907
# Epoch 17/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4662 - accuracy: 0.8048
# Epoch 18/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.4530 - accuracy: 0.8076
# Epoch 19/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.4534 - accuracy: 0.7992
# Epoch 20/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4605 - accuracy: 0.8006
# Epoch 21/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.4511 - accuracy: 0.7963
# Epoch 22/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.4631 - accuracy: 0.7963
# Epoch 23/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4410 - accuracy: 0.8118
# Epoch 24/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4529 - accuracy: 0.8048
# Epoch 25/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4713 - accuracy: 0.7865
# Epoch 26/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4400 - accuracy: 0.8104
# Epoch 27/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.4514 - accuracy: 0.7963
# Epoch 28/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4811 - accuracy: 0.7949
# Epoch 29/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4538 - accuracy: 0.8006
# Epoch 30/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.4566 - accuracy: 0.7921

# %% [markdown]
# ## 히든 레이어 더 쌓아 학습해 보자

# %% [markdown]
# ![레이어추가](https://cdn.educba.com/academy/wp-content/uploads/2020/03/DNN-Neural-Network-1.png.webp)

# %%
# Sequential 모델 만들기 --> model 변수 저장
# input layer : (6, )
# hidden layer : 32 unit , activation='relu'
# hidden layer : 16 unit , activation='relu'
# output layer : 2 unit , activation='softmax'

# %%
# 모델 컴파일 : compile
# loss='sparse_categorical_crossentropy'
# optimizer='adam'
# metrics=['accuracy']

# %%
# 모델 학습 : fit
# X_train, y_train, epochs=30, batch_size=8
# 학습결과 저장 : history
# Out:
# Epoch 1/30
# 89/89 [==============================] - 2s 5ms/step - loss: 1.3532 - accuracy: 0.6587
# Epoch 2/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6572 - accuracy: 0.6770
# Epoch 3/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6571 - accuracy: 0.6798
# Epoch 4/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6431 - accuracy: 0.6629
# Epoch 5/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5994 - accuracy: 0.6868
# Epoch 6/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.6033 - accuracy: 0.6854
# Epoch 7/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5813 - accuracy: 0.6966
# Epoch 8/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5839 - accuracy: 0.7177
# Epoch 9/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5571 - accuracy: 0.7346
# Epoch 10/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5427 - accuracy: 0.7683
# Epoch 11/30
# 89/89 [==============================] - 0s 5ms/step - loss: 0.5373 - accuracy: 0.7500
# Epoch 12/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5481 - accuracy: 0.7528
# Epoch 13/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5238 - accuracy: 0.7626
# Epoch 14/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5268 - accuracy: 0.7472
# Epoch 15/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5206 - accuracy: 0.7514
# Epoch 16/30
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5081 - accuracy: 0.7697
# Epoch 17/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4904 - accuracy: 0.7837
# Epoch 18/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4866 - accuracy: 0.7781
# Epoch 19/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.7823
# Epoch 20/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4842 - accuracy: 0.7921
# Epoch 21/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4976 - accuracy: 0.7865
# Epoch 22/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 0.7823
# Epoch 23/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.8006
# Epoch 24/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4509 - accuracy: 0.8118
# Epoch 25/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.7949
# Epoch 26/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4558 - accuracy: 0.8104
# Epoch 27/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4651 - accuracy: 0.7935
# Epoch 28/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4655 - accuracy: 0.8146
# Epoch 29/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4616 - accuracy: 0.8062
# Epoch 30/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.8076

# %% [markdown]
# ## DNN 학습때 학습이 잘되는지 보기 위해 모르는 데이터(valid data)로 평가해 보자

# %%
# Sequential 모델 만들기 --> model 변수 저장
# input layer : (6, )
# hidden layer : 32 unit , activation='relu'
# hidden layer : 16 unit , activation='relu'
# output layer : 2 unit , activation='softmax'

# %%
# 모델 컴파일 : compile
# loss='sparse_categorical_crossentropy'
# optimizer='adam'
# metrics=['accuracy']

# %%
# 모델 학습 : fit
# X_train, y_train, epochs=30, batch_size=8, validation_data=(X_test, y_test)
# 학습결과 저장 : history

# validation_data 옵션을 추가해서 모델 학습에 대한 평가를 할수 있다.
# 즉, 모르는 데이터에 대해 성능평가 잘 나온다면 좋은것이다.
# Out:
# Epoch 1/30
# 89/89 [==============================] - 1s 5ms/step - loss: 2.8767 - accuracy: 0.5154 - val_loss: 0.5949 - val_accuracy: 0.7263
# Epoch 2/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.6332 - accuracy: 0.6601 - val_loss: 0.5876 - val_accuracy: 0.6536
# Epoch 3/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5930 - accuracy: 0.6980 - val_loss: 0.5602 - val_accuracy: 0.7263
# Epoch 4/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5884 - accuracy: 0.7177 - val_loss: 0.5773 - val_accuracy: 0.7207
# Epoch 5/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5617 - accuracy: 0.7317 - val_loss: 0.6033 - val_accuracy: 0.6145
# Epoch 6/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5554 - accuracy: 0.7458 - val_loss: 0.5221 - val_accuracy: 0.7207
# Epoch 7/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5402 - accuracy: 0.7444 - val_loss: 0.5423 - val_accuracy: 0.7039
# Epoch 8/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5144 - accuracy: 0.7725 - val_loss: 0.5049 - val_accuracy: 0.7709
# Epoch 9/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5278 - accuracy: 0.7654 - val_loss: 0.4945 - val_accuracy: 0.7709
# Epoch 10/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5123 - accuracy: 0.7697 - val_loss: 0.4865 - val_accuracy: 0.7821
# Epoch 11/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5123 - accuracy: 0.7711 - val_loss: 0.4751 - val_accuracy: 0.7933
# Epoch 12/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5075 - accuracy: 0.7697 - val_loss: 0.4689 - val_accuracy: 0.7765
# Epoch 13/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5116 - accuracy: 0.7739 - val_loss: 0.4810 - val_accuracy: 0.7821
# Epoch 14/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4995 - accuracy: 0.7907 - val_loss: 0.4540 - val_accuracy: 0.7989
# Epoch 15/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4893 - accuracy: 0.7823 - val_loss: 0.4650 - val_accuracy: 0.7933
# Epoch 16/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4962 - accuracy: 0.7879 - val_loss: 0.5211 - val_accuracy: 0.7542
# Epoch 17/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4794 - accuracy: 0.7921 - val_loss: 0.4671 - val_accuracy: 0.7877
# Epoch 18/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4814 - accuracy: 0.7935 - val_loss: 0.5217 - val_accuracy: 0.7598
# Epoch 19/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4948 - accuracy: 0.7921 - val_loss: 0.4617 - val_accuracy: 0.7654
# Epoch 20/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4595 - accuracy: 0.7992 - val_loss: 0.4490 - val_accuracy: 0.7989
# Epoch 21/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4620 - accuracy: 0.7978 - val_loss: 0.4543 - val_accuracy: 0.7821
# Epoch 22/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4747 - accuracy: 0.7935 - val_loss: 0.4667 - val_accuracy: 0.7933
# Epoch 23/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4744 - accuracy: 0.7992 - val_loss: 0.4303 - val_accuracy: 0.8045
# Epoch 24/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4614 - accuracy: 0.7963 - val_loss: 0.4441 - val_accuracy: 0.8156
# Epoch 25/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4701 - accuracy: 0.7865 - val_loss: 0.4540 - val_accuracy: 0.8268
# Epoch 26/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4546 - accuracy: 0.7992 - val_loss: 0.4333 - val_accuracy: 0.7989
# Epoch 27/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4557 - accuracy: 0.8034 - val_loss: 0.4422 - val_accuracy: 0.7877
# Epoch 28/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7879 - val_loss: 0.4666 - val_accuracy: 0.8212
# Epoch 29/30
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4610 - accuracy: 0.8034 - val_loss: 0.4463 - val_accuracy: 0.7877
# Epoch 30/30
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.8020 - val_loss: 0.4376 - val_accuracy: 0.7877

# %% [markdown]
# ---

# %% [markdown]
# # 8. 딥러닝 성능 평가

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# matplotlib 이용하여 그래프 그리기
# 1. plot 그리기 : 입력  history.history['loss'], 'r'
# 2. plot 그리기 : 입력  history.history['accuracy'], 'b'
# 3. plot 그리기 : 입력  history.history['val_loss'], 'y'
# 4. plot 그리기 : 입력  history.history['val_accuracy'], 'k'
# 5. title : 'Loss and Accuracy'
# 6. xlabel : "Epochs"
# 7. ylabel : "Loss"
# 8. ["Loss", "Accuracy", 'val_loss', 'val_accuracy']
# 7. plt.show()
