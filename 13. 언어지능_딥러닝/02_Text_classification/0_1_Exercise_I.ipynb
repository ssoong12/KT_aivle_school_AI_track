# %% [markdown]
# # Sentiment Classification & Embedding I
#
# * Before RNN & Embedding Layer

# %% [markdown]
# # 01. What data we use?

# %%
import pandas as pd
import zipfile as zf

# %%
df = pd.read_csv('https://raw.githubusercontent.com/corazzon/KaggleStruggle/master/word2vec-nlp-tutorial/data/labeledTrainData.tsv', sep='\t')

# %%
df.head()

# %%
df.shape

# %%
labels = df[['sentiment']]
y = labels.values
reviews = df[['review']]

# %%
labels.head()

# %%
reviews.head()

# %%
labels = labels['sentiment'].tolist()
reviews = reviews['review'].tolist()

# %%
def preview(i):
    if labels[i] == 1 :
        label = 'positive'
    else:
        label = 'negative'
    print(label + "  :  " + reviews[i][:80] + "...")

# %%
len(reviews)

# %%
reviews[0]

# %%
labels[0]

# %% [markdown]
# # Discussion : 무엇으로 무엇을 어떻게 예측하려 하는가?

# %%
print("labels.txt  :  reviews.txt")
print("--------------------------")
preview(2490)
preview(12786)
preview(6267)
preview(24965)
preview(11947)
preview(2312)

# %% [markdown]
# # Q1. Tokenizer를 이용하여, TFIDF vector를 만들 것.
#
# * 만들고 나서 x와 y를 제작한다.
#     * reviews --> x
#     * labels --> y
#     * 80%는 트레이닝 셋으로, 20%는 테스트 셋으로
#
#
#
# * Bag of Words : Binary ver
# > texts_to_matrix(reviews, mode='binary')
# * Bag of Words : Counting ver
# > texts_to_matrix(reviews, mode='count')
# * Tf-IDF
# > texts_to_matrix(reviews, mode='tfidf')

# %%
#####################
## Your Codes Here ##
#####################

# %%
#####################
## Your Codes Here ##
#####################

# %%
#####################
## Your Codes Here ##
#####################

# %% [markdown]
# # 모델링!
#
# * 두 개의 히든레이어를 사용한다.
#     1. 노드 2048짜리 FC layer
#     2. 노드 1024짜리 FC layer
# * 적절히 아웃풋레이어를 구성한다
# * 학습시킨다.

# %%
#####################
## Your Codes Here ##
#####################

# %%
#####################
## Your Codes Here ##
#####################

# %% [markdown]
# # 테스트 데이터 위에서 평가.
#
# 1. accuracy는?
# 2. positive에 대한 recall은?
# 3. negative에 대한 recall은?
