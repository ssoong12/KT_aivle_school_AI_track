# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/admission.png?raw=true" width=800 align="left"/>

# %% [markdown]
# # 실습 내용
#
# - Admission 데이터로 모델링합니다.
# - SVM 알고리즘으로 모델링합니다.

# %% [markdown]
# # 1.환경 준비
#
# - 기본 라이브러리와 대상 데이터를 가져와 이후 과정을 준비합니다.

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/jangrae/csv/master/admission_simple.csv'
data = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해
#
# - 분석할 데이터를 충분히 이해할 수 있도록 다양한 탐색 과정을 수행합니다.

# %%
# 상위 몇 개 행 확인
data.head()
# Out:
#    GRE  TOEFL  RANK  SOP  LOR   GPA  RESEARCH  ADMIT
# 0  337    118     4  4.5  4.5  9.65         1      1
# 1  324    107     4  4.0  4.5  8.87         1      1
# 2  316    104     3  3.0  3.5  8.00         1      0
# 3  322    110     3  3.5  2.5  8.67         1      1
# 4  314    103     2  2.0  3.0  8.21         0      0

# %%
# 기술통계 확인
data.describe()
# Out:
#               GRE       TOEFL        RANK         SOP        LOR         GPA  \
# count  500.000000  500.000000  500.000000  500.000000  500.00000  500.000000
# mean   316.472000  107.192000    3.114000    3.374000    3.48400    8.576440
# std     11.295148    6.081868    1.143512    0.991004    0.92545    0.604813
# min    290.000000   92.000000    1.000000    1.000000    1.00000    6.800000
# 25%    308.000000  103.000000    2.000000    2.500000    3.00000    8.127500
# 50%    317.000000  107.000000    3.000000    3.500000    3.50000    8.560000
# 75%    325.000000  112.000000    4.000000    4.000000    4.00000    9.040000
# max    340.000000  120.000000    5.000000    5.000000    5.00000    9.920000
#
#          RESEARCH       ADMIT
# count  500.000000  500.000000
# mean     0.560000    0.436000
# std      0.496884    0.496384
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      1.000000    0.000000
# 75%      1.000000    1.000000
# ...

# %%
# 범주값 개수 확인
data['ADMIT'].value_counts()
# Out:
# 0    282
# 1    218
# Name: ADMIT, dtype: int64

# %%
# 변수 정보 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   GRE       500 non-null    int64
#  1   TOEFL     500 non-null    int64
#  2   RANK      500 non-null    int64
#  3   SOP       500 non-null    float64
#  4   LOR       500 non-null    float64
#  5   GPA       500 non-null    float64
#  6   RESEARCH  500 non-null    int64
#  7   ADMIT     500 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 31.4 KB

# %%
# 상관관계 확인
data.corr()
# Out:
#                GRE     TOEFL      RANK       SOP       LOR       GPA  \
# GRE       1.000000  0.827200  0.635376  0.613498  0.524679  0.825878
# TOEFL     0.827200  1.000000  0.649799  0.644410  0.541563  0.810574
# RANK      0.635376  0.649799  1.000000  0.728024  0.608651  0.705254
# SOP       0.613498  0.644410  0.728024  1.000000  0.663707  0.712154
# LOR       0.524679  0.541563  0.608651  0.663707  1.000000  0.637469
# GPA       0.825878  0.810574  0.705254  0.712154  0.637469  1.000000
# RESEARCH  0.563398  0.467012  0.427047  0.408116  0.372526  0.501311
# ADMIT     0.701671  0.680503  0.618367  0.606876  0.536527  0.752196
#
#           RESEARCH     ADMIT
# GRE       0.563398  0.701671
# TOEFL     0.467012  0.680503
# RANK      0.427047  0.618367
# SOP       0.408116  0.606876
# LOR       0.372526  0.536527
# GPA       0.501311  0.752196
# RESEARCH  1.000000  0.503104
# ADMIT     0.503104  1.000000

# %% [markdown]
# # 3.데이터 준비
#
# - 전처리 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# **1) x, y 분리**
#
# - target 변수를 명확히 지정합니다.
# - target을 제외한 변수를 x 데이터프레임으로 선언합니다.
# - y 데이터프레임은 target 변수만을 가집니다.

# %%
# target 확인
target = 'ADMIT'

# 데이터 분리
# x = data.drop(target, axis=1)
# 'GRE', 'GPA' 열만 x 변수로 설정
x = data[['GRE', 'GPA']]
y = data[target]

# %% [markdown]
# **2) 학습용, 평가용 데이터 분리**
#
# - 학습용, 평가용 데이터를 적절한 비율로 분리합니다.
# - 반복 실행 시 동일한 결과를 얻기 위해 random_state 옵션을 지정합니다.

# %%
# 모듈 불러오기
from sklearn.model_selection import train_test_split

# 7:3으로 분리
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %% [markdown]
# **3) 정규화**
#
# - SVM 알고리즘을 사용하기 위해 정규화를 진행합니다.

# %%
# 모듈 불러오기
from sklearn.preprocessing import MinMaxScaler

# 정규화
scaler = MinMaxScaler()
scaler.fit(x_train) # 스케일러야 공부하자
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test) # 좀전에 공부한 걸로 정규화해주세요 
# 넘파이 어레이가 되어버려용


# 마진이 거리니까 거리를 구하는 것이니 당연히 정규화를 해야 함 
# 정규화가 필한 것은 KNN, SVM 나머지는 정규화 써도 되는데 이 둘만 필요하다.

# %% [markdown]
# # 4.모델링
#
# - 본격적으로 모델을 선언하고 학습하고 평가하는 과정을 진행합니다.

# %%
# 1단계: 불러오기
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report

# %%
# 2단계: 선언하기
model = SVC(kernel='linear', C=1) # cost default가 1

# %%
# 3단계: 학습하기
model.fit(x_train, y_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
# 4단계: 예측하기
y_pred = model.predict(x_test)

# %%
# 5단계 평가하기
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# 어드미션을 서포트벡타머신으로 해줬더니 정확도가 91(accuracy)정도 나왔넹
# Out:
# [[78  6]
#  [ 8 58]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        84
#            1       0.91      0.88      0.89        66
#
#     accuracy                           0.91       150
#    macro avg       0.91      0.90      0.90       150
# weighted avg       0.91      0.91      0.91       150

# %% [markdown]
# # 5.기타
#
# - 기타 필요한 내용이 있으면 진행합니다.

# %% [markdown]
# - #### model = SVC(kernel='linear', C=1) # cost default가 1

# %%
#  시각화
xx = np.linspace(0, 1, 30)
yy = np.linspace(0, 1, 30)
yy, xx = np.meshgrid(yy, xx)
xy = np.vstack([xx.ravel(), yy.ravel()]).T
z = model.decision_function(xy).reshape(xx.shape)

plt.figure(figsize=(8, 5))
sns.scatterplot(x=x_train[:,0], y=x_train[:, 1], hue=y_train, s=20)
# plt.scatter(model.support_vectors_[:, 0], 
#             model.support_vectors_[:, 1], 
#             s=50,
#             linewidth=0.5,
#             facecolors='none', 
#             color='r')
plt.contour(xx, yy, z, 
            levels=[-1, 0, 1], 
            alpha=0.5,
            colors=['gray', 'red', 'gray'],
            linestyles=['--', '-', '--'])

plt.xlabel('GRE')
plt.ylabel('GPA')
plt.show()
# 지알이 지피에이 두개만 가지고 했을 때 모델을 기준으로 왼쪽은 0 오른쪽은 1로 판단 - linear 
# >> GRE랑 GPA만 고른 이유는 시각화하기 위해서, 다른 거 안 쓴 이유는 다 쓰면 차원이 높아져서 시각화하기 어려움
# linear든 rbf나 별차이 없는데 오히려 이 경우에 리니어가 더 좋다
# 알비에프랑 폴리일 경우 코스트랑 콤마를 얼마 해야할지 넣는 걸 튜닝이라 한다.
# 커널이 무엇일 때 좋냐? 넣어줄 파라미터도 우리가 잘 정해야 함

# %% [markdown]
# - #### model = SVC(kernel='rbf', C=0.1) # cost default가 1
# ![image.png](attachment:image.png)
